# %%
# Problem 1
states = {
"California":'Los Angeles',
'New York'  : 'Albany',
'Hawaii'    : 'Honolulu',
'Alaska'    : 'Juneau',
'Texas'     : 'Austin'
}

print(type(states))
# Second method of solving
states1 = dict([
    ("California", 'Los Angeles'),
    ('New York', 'Albany'),
    ('Hawaii', 'Honolulu'),
    ('Alaska', 'Juneau'),
    ('Texas', 'Austin')
])

print(type(states1))
# Problem 2
# - Retrieve the **value** associated with the key **"California"**.
print(states['California'])

# - Add a new **key-value pair** for **Florida** and its capital to the dictionary.
states['Florida'] = 'Tallahasee'

# - Update the value for **"California"** to **"Sacramento"**.
states['California'] = 'Sacramento'

# - Remove the key-value pair for **"Alaska"** from the dictionary.
del states['Alaska']

print(states)
# **`playlist`** with **at least 6 key-value pairs**:
#   - Each **key** should be an **artist name**.
#   - Each **value** should be a **song by that artist**.
playlist = {
    'Lil John': 'Get Low',
    'Usher': 'Yeah',
    'T-Pain': 'Buy U a Drank',
    'Hinder': 'Lips of an Angel',
    'Nickelback': 'Rockstar'
}

# - Use a **for loop** to print all the **artist names** in the playlist.
for name in playlist:
    print(name)

# - Use a **for loop** to print all the **song titles** in the playlist.

# for song in playlist.values():
#     print(song)

for name in playlist:
    print(playlist[name])

# - Use a **for loop** to print the following statement for each entry:
#   **"(Song Name) by (Artist) is in the current playlist."**
for artist, song in playlist.items():
    print(f'{song} by {artist} is in the current playlist.')

# - Remove the **last key-value pair** from the dictionary.
playlist.popitem()

# - Add the song **"Anti-Hero" by Taylor Swift** to the playlist.
playlist['Taylor Swift'] = 'Anti-Hero'

# - Update one of the songs so that the title begins with **"REMIX"**.
playlist['T-Pain'] = 'Remix ' + playlist['T-Pain']
# Out:
# <class 'dict'>
# <class 'dict'>
# Los Angeles
# {'California': 'Sacramento', 'New York': 'Albany', 'Hawaii': 'Honolulu', 'Texas': 'Austin', 'Florida': 'Tallahasee'}
# Lil John
# Usher
# T-Pain
# Hinder
# Nickelback
# Get Low
# Yeah
# Buy U a Drank
# Lips of an Angel
# Rockstar
# Get Low by Lil John is in the current playlist.
# Yeah by Usher is in the current playlist.
# Buy U a Drank by T-Pain is in the current playlist.
# Lips of an Angel by Hinder is in the current playlist.
# Rockstar by Nickelback is in the current playlist.
